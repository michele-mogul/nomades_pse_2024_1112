# %% [markdown]
# <h1> Hello </h1>

# %%
import numpy as np
a = np.array([1,2,3,2,5])
b = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 2, 5])

# %%
b = a * 10

# %%
import matplotlib.pyplot as plt
plt.plot(a, b, "r-D", label= "a*10")
plt.legend()
plt.show()
